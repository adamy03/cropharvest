# %%
from cropharvest.datasets import CropHarvest
import geopandas as gpd 
import pandas

# %%
from cropharvest.datasets import (countries, Task, BaseDataset, CropHarvest)
bbox = countries.get_country_bbox('Togo')[0]
root = 'data\HarvestData'
task = Task(bbox,  target_label = 'crop')
data = CropHarvest(root, task, download=True)
# Out:
#   1%|▏         | 11401216/782628016 [00:20<23:37, 544183.50it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#       3 root = 'data\HarvestData'
#       4 task = Task(bbox, None, False, None, True)
# ----> 5 data = CropHarvest(root, task, download=True)
#
# File ~\anaconda3\envs\CropHarvest\lib\site-packages\cropharvest\datasets.py:203, in CropHarvest.__init__(self, root, task, download, val_ratio, is_val)
#     195 def __init__(
#     196     self,
#     197     root,
#    (...)
#     201     is_val: bool = False,
#     202 ):
# --> 203     super().__init__(root, download, filenames=(FEATURES_DIR, TEST_FEATURES_DIR))
#     205     labels = CropHarvestLabels(root, download=download)
#     206     if task is None:
#
# ...

# %%
from cropharvest.countries import get_countries
get_countries()
# Out:
# ['Zimbabwe',
#  'Zambia',
#  'Yemen',
#  'Vietnam',
#  'Venezuela',
#  'Vatican City',
#  'Vanuatu',
#  'Uzbekistan',
#  'Uruguay',
#  'Federated States of Micronesia',
#  'Marshall Islands',
#  'Northern Mariana Islands',
#  'United States Virgin Islands',
#  'Guam',
#  'American Samoa',
#  'Puerto Rico',
#  'United States of America',
#  'South Georgia and the South Sandwich Islands',
#  'British Indian Ocean Territory',
#  'Saint Helena',
#  'Pitcairn Islands',
#  'Anguilla',
#  'Falkland Islands',
#  'Cayman Islands',
#  'Bermuda',
#  'British Virgin Islands',
#  'Turks and Caicos Islands',
#  'Montserrat',
#  'Jersey',
#  'Guernsey',
#  'Isle of Man',
#  'United Kingdom',
#  'United Arab Emirates',
#  'Ukraine',
#  'Uganda',
#  'Turkmenistan',
#  'Turkey',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tonga',
#  'Togo',
#  'East Timor',
#  'Thailand',
#  'Tanzania',
#  'Tajikistan',
#  'Taiwan',
#  'Syria',
#  'Switzerland',
#  'Sweden',
#  'eSwatini',
#  'Suriname',
# ...

# %%
from cropharvest.utils import download_and_extract_archive

download_and_extract_archive('data\HarvestData', 'Togo')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [2], in <module>
#       1 from cropharvest.utils import download_and_extract_archive
# ----> 3 download_and_extract_archive('data\HarvestData', 'Togo')
#
# File ~\anaconda3\envs\CropHarvest\lib\site-packages\cropharvest\utils.py:62, in download_and_extract_archive(root, filename)
#      60     url = f"{DATASET_URL}/files/{targz_path.name}?download=1"
#      61     if not targz_path.exists():
# ---> 62         download_from_url(url, targz_path_str)
#      63     extract_archive(targz_path)
#      64 else:
#
# File ~\anaconda3\envs\CropHarvest\lib\site-packages\cropharvest\utils.py:35, in download_from_url(url, filename, chunk_size)
#      33 def download_from_url(url: str, filename: str, chunk_size: int = 1024) -> None:
#      34     with open(filename, "wb") as fh:
# ...

# %%
countries = gpd.read_file('data\Country_Shapefiles')
countries.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0  Admin-0 country          1          3   Zimbabwe    ZWE         0      2
# 1  Admin-0 country          1          3     Zambia    ZMB         0      2
# 2  Admin-0 country          1          3      Yemen    YEM         0      2
# 3  Admin-0 country          3          2    Vietnam    VNM         0      2
# 4  Admin-0 country          5          3  Venezuela    VEN         0      2
#
#                 TYPE      ADMIN ADM0_A3  ...          NAME_KO    NAME_NL  \
# 0  Sovereign country   Zimbabwe     ZWE  ...     ì§ë°ë¸ì¨   Zimbabwe
# 1  Sovereign country     Zambia     ZMB  ...        ì ë¹ì     Zambia
# 2  Sovereign country      Yemen     YEM  ...           ìë©      Jemen
# 3  Sovereign country    Vietnam     VNM  ...        ë² í¸ë¨    Vietnam
# 4  Sovereign country  Venezuela     VEN  ...  ë² ë¤ììë¼  Venezuela
#
# ...

# %%
togo_index = countries[countries['SOVEREIGNT'] == 'Togo']
togo_poly = togo_index['geometry']
togo_poly
# Out:
# 40    POLYGON ((0.90049 10.99326, 0.87480 10.88574, ...
# Name: geometry, dtype: geometry

# %%
evaluation_datasets = CropHarvest.create_benchmark_datasets(DATA_DIR)
# Out:
# C:\Users\adamf\anaconda3\envs\CropHarvest\lib\site-packages\cropharvest\countries.py:85: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   BBox.polygon_to_bbox(x, f"{country_name}_{idx}") for idx, x in enumerate(polygon)
# 61467648it [03:30, 292577.75it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 evaluation = CropHarvest.create_benchmark_datasets(root = 'data/test_data')
#
# File ~\anaconda3\envs\CropHarvest\lib\site-packages\cropharvest\datasets.py:376, in CropHarvest.create_benchmark_datasets(cls, root, balance_negative_crops, download)
#     374         if task.id not in [x.id for x in output_datasets]:
#     375             if country_bbox.contains_bbox(bbox):
# ...

# %%
from cropharvest import countries

print(countries.get_countries())
# Out:
# ['Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 'Venezuela', 'Vatican City', 'Vanuatu', 'Uzbekistan', 'Uruguay', 'Federated States of Micronesia', 'Marshall Islands', 'Northern Mariana Islands', 'United States Virgin Islands', 'Guam', 'American Samoa', 'Puerto Rico', 'United States of America', 'South Georgia and the South Sandwich Islands', 'British Indian Ocean Territory', 'Saint Helena', 'Pitcairn Islands', 'Anguilla', 'Falkland Islands', 'Cayman Islands', 'Bermuda', 'British Virgin Islands', 'Turks and Caicos Islands', 'Montserrat', 'Jersey', 'Guernsey', 'Isle of Man', 'United Kingdom', 'United Arab Emirates', 'Ukraine', 'Uganda', 'Turkmenistan', 'Turkey', 'Tunisia', 'Trinidad and Tobago', 'Tonga', 'Togo', 'East Timor', 'Thailand', 'Tanzania', 'Tajikistan', 'Taiwan', 'Syria', 'Switzerland', 'Sweden', 'eSwatini', 'Suriname', 'South Sudan', 'Sudan', 'Sri Lanka', 'Spain', 'South Korea', 'South Africa', 'Somalia', 'Somaliland', 'Solomon Islands', 'Slovakia', 'Slovenia', 'Singapore', 'Sier
# ...
